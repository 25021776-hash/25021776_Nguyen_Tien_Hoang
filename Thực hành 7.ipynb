# %%
#W7A1
def binary_search(arr,left,right,target):
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1
arr = list(map(int, input().split()))
arr.sort()
n = int(input())
print(binary_search(arr, 0,len(arr) - 1, n))
# Out:
# -1

# %%
#W7A2
def count_occurrences(arr,x):
    cnt = 0
    for i in arr:
        if i == x:
            cnt += 1
    return cnt
arr = list(map(int, input().split()))
arr.sort()
n = int(input())
print(count_occurrences(arr,n))
# Out:
# 0

# %%
#W7A3
def bubblesort(arr):
    n = len(arr)
    for i in range(n):
        swap = True
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swap = False
        if swap == True:
            return arr

def selectionsort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
arr = list(map(int, input().split()))
print(selectionsort(arr))
print(bubblesort(arr))
# Out:
# [1, 2, 2, 3, 3, 4, 5, 6, 7, 8]
# [1, 2, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
#W7A4
a = list(map(int, input().split()))
cnt = [0] * 10000000
for i in a:
    cnt[i] += 1
i,minvalue=0, -10000000000000
for i in a:
    if cnt[i] != 0 and cnt[i] > minvalue:
        minvalue = cnt[i]
        j = i
print(f'{j} xuat hien nhieu nhat,som nhat,{minvalue} lan ')
# Out:
# 2 xuat hien nhieu nhat,som nhat,3 lan

# %%
#W7A5
a = list(map(int, input().split()))
c = int(input())
cnt = 0
for i in range(len(a)):
    for j in range(i + 1,len(a)):
        if a[i] + a[j] == c:
            cnt += 1
print(cnt)

# %%
#W7A6
a = []
n = int(input())
for i in range(n):
    x = list(map(int, input().split()))
    a.append(x)
b = [x for small_list in a for x in small_list ]
print(b)
# Out:
# [4, 5, 6, 9, 0, 1, 1, 2, 0, 0, 1]

# %%
#W7A7

# %%
#W7A9
a = list(map(int, input().split()))
b= []
for i in range(len(a)):
    cnt = 0
    for j in range(i + 1, len(a)):
        if a[i] > a[j]:
            cnt += 1
    b.append(cnt)
print(b)

# %%
#W7A10
a = list(map(int, input().split()))
k = int(input())
res = 0
for i in range(len(a)):
    for j in range(i+1, len(a)):
        m = sum(a[i:j])
        if m % k > res:
            res = m % k
print(res)
# Out:
# 1

# %%
#W7A11
s = input().split()
m = input()
cnt = 0
for i in s:
    if i == m:
        cnt += 1
print(cnt)

# %%
#W7A12
a = input()
b = input()
c = input()
d = input()
mylist = [a,b,c,d]
mylist.sort()
for i in mylist:
    if i == a :
        print("A",end=" ")
    elif i == b :
        print("B",end=" ")
    elif i == c :
        print("C",end=" ")
    elif i == d :
        print("D",end=" ")

# %%
#W7A13
a = list(map(int, input().split()))
a.sort()
min1 = 0
for i in range(len(a)):
    b = []
    for j in range(i + 1, len(a)):
        if a[i] == a[j] or a[i] - a[j] == -1:
            b.append(a[j])
        else:
            break
    b.append(a[i])
    if len(b) > min1:
        min1 = len(b)
print(min1)

# %%
#W7A14
a = list(map(int, input().split()))
check = 0
for i in range(len(a) - 1,-1,-1):
    if a[i] == 7:
        print(i,end=" ")
        check = 1
if check == 0:
    print("NOT FOUND")
# Out:
# 4 3

# %%
#W7A15
a = list(map(int, input().split()))
s1,s2 = 0,0
for i in range(len(a)):
    if a[i] == "NEMO":
        if i == len(a) - 1:
            s1 = a[i - 1]
            s2 = a[0]
        else:
            s1 = a[i - 1]
            s2 = a[i + 1]
print(f'{s1} and {s2}')
